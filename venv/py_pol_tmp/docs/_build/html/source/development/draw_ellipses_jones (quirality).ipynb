# %% [markdown]
# # Drawing ellipses for Jones vectors
#
# https://en.wikipedia.org/wiki/Stokes_parameters

# %%
# %matplotlib notebook 
from py_pol import degrees, np
from py_pol.jones_vector import Jones_vector
import matplotlib.pyplot as plt
from py_pol.drawings import draw_ellipse_jones, draw_ellipses_jones

# %% [markdown]
# ## Only 1 vector - for Jones_vector class

# %%
j0s=Jones_vector('j0')
j0s.circular_light(amplitude=1, kind='r')
j0s.elliptical_light(a=10, b=20, phase=45*degrees, angle=45*degrees)
# Out:
# matrix([[17.07106781+10.j],
#         [ 2.92893219+10.j]])

# %%
j0s.draw_ellipse(draw_arrow=True)
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# (<Figure size 640x480 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fa2a249b1d0>)

# %%
Jones_vectors_0=[]

j0=Jones_vector('j0')
j0.linear_light(amplitude=1, angle=0*degrees)


angles = np.linspace(0, 180*degrees, 6, endpoint=False)

for i, angle in enumerate(angles):
    ji=j0.rotate(angle=angle, keep=False)
    Jones_vectors_0.append(ji)
    print(ji)
    
print (Jones_vectors_0)
# Out:
# j0 = [1.0; 0.0]'
# j0 @30.00 deg = [0.866; 0.5]'
# j0 @60.00 deg = [0.5; 0.866]'
# j0 @90.00 deg = [0.0; 1.0]'
# j0 @120.00 deg = [-0.5; 0.866]'
# j0 @150.00 deg = [-0.866; 0.5]'
# [j0 = [1.0; 0.0]', j0 @30.00 deg = [0.866; 0.5]', j0 @60.00 deg = [0.5; 0.866]', j0 @90.00 deg = [0.0; 1.0]', j0 @120.00 deg = [-0.5; 0.866]', j0 @150.00 deg = [-0.866; 0.5]']
# /home/luismiguel/bitbucket/py_pol/py_pol/jones_vector.py:803: RuntimeWarning: invalid value encountered in sqrt
#   b = np.sqrt(b2)

# %%
Jones_vectors_1=[]

j0=Jones_vector('j0')
j0.elliptical_light(a=20, b=20, phase=45*degrees, angle=0*degrees)


angles = np.linspace(0, 180*degrees, 6, endpoint=False)

for i, angle in enumerate(angles):
    ji=j0.rotate(angle=angle, keep=False)
    Jones_vectors_1.append(ji)
    print(ji)
    
print (Jones_vectors_1)
# Out:
# j0 = [(20+0j); (14.1421+14.1421j)]'
# j0 @30.00 deg = [(10.2494-7.0711j); (22.2474+12.2474j)]'
# j0 @60.00 deg = [(-2.2474-12.2474j); (24.3916+7.0711j)]'
# j0 @90.00 deg = [(-14.1421-14.1421j); (20+0j)]'
# j0 @120.00 deg = [(-22.2474-12.2474j); (10.2494-7.0711j)]'
# j0 @150.00 deg = [(-24.3916-7.0711j); (-2.2474-12.2474j)]'
# [j0 = [(20+0j); (14.1421+14.1421j)]', j0 @30.00 deg = [(10.2494-7.0711j); (22.2474+12.2474j)]', j0 @60.00 deg = [(-2.2474-12.2474j); (24.3916+7.0711j)]', j0 @90.00 deg = [(-14.1421-14.1421j); (20+0j)]', j0 @120.00 deg = [(-22.2474-12.2474j); (10.2494-7.0711j)]', j0 @150.00 deg = [(-24.3916-7.0711j); (-2.2474-12.2474j)]']

# %%
ax, fig=draw_ellipses_jones(Jones_vectors_0, filename='', draw_arrow=True)
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
ax, fig=draw_ellipses_jones(Jones_vectors_1, filename='', draw_arrow=True)
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %% [markdown]
# ## Chirality
#
# Issue #3: Chirality indicated in draw_ellipse_jones (optbrea/py_pol)

# %%
ax, fig=draw_ellipses_jones(Jones_vectors_0, draw_arrow=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-620a87011a24> in <module>
# ----> 1 ax, fig=draw_ellipses_jones(Jones_vectors_0, draw_arrow=True)
#
# NameError: name 'Jones_vectors_0' is not defined

# %%
ax, fig=draw_ellipses_jones(Jones_vectors_1, draw_arrow=True)
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
Jones_vectors_1[0]
# Out:
# j0 = [(1+0j); (0.7071+0.7071j)]'

# %% [markdown]
# ## From class

# %%
ax, fig=draw_ellipses_jones(Jones_vectors_1, draw_arrow=True)
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
